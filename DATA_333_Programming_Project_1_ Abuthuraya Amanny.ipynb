# %%
#Asking for names

cont="y"
while cont.lower()=="y":
    print("Welcome to the AI Bot!")
    f_name=input("What is your first name? ")
    l_name=input("What is your last name?")


    #greeting with full name
    print("Sound great" + " " + f_name + " " + l_name + "." + " Thank you for using me")


    #design and setences
    print("__________________________________")
    print("Before we get started, I would need some information from you. Please be kind to me, as I am only a program and I am no human.")
    choice=input("Would you like to continue with me or be transferred to a human to help you make a purchase? (continue/transfer)")

    #If "Continue":
    if choice.lower()=="continue":

        #taking info
        email=input("What is your email address?")
        phone=input("What is your phone number?")
        num_purchases=int(input("How many chatbot licenses would you like to purchase?"))
        total=num_purchases*75


        #Asking about support
        support_plan= input("Would you like to purchase the Gold support plan with your normal plan? It gives you priority support. (y/n)")
        print()
        if support_plan.lower()=="y":
            if num_purchases>=1 and num_purchases<=50:
                license_supp=500
                print("The Gold Support plan costs $500/year for license purchases 1 - 50.")
                print()
                total+= 500*num_purchases

            elif num_purchases>=51 and num_purchases<=99 :
                license_supp=350
                print("The Gold Support plan costs $350/year for license purchases 51 - 99.")
                print()
                total+= 350*num_purchases
            elif num_purchases>=100:
                license_supp=250
                print("The Gold Support plan costs $250/year for license purchases 100+.")
                print()
                total+= 250*num_purchases
        else:
            license_supp=0



        #Completing info and finishing purchase
        choice_purchase=input("Would you like to check out? (y/n)")
        if choice_purchase.lower()=="y":


            #to calculate taxes and update total
            taxes = total*10/100


            #Credit Card Info
            cc=input("Please provide your credit card number")
            exp_date=input("Please provide your expiration date of your credit card")
            cvc=input("Please provide your CVC number. It can be found on the back of your card.")
            zip_code=input("Please provide your zip code: ")
            print("Here's your receipt:")
            print("Number of Licenses: ",num_purchases)
            print ("Number of support plans: ", license_supp*num_purchases)
            print("Subtotal: ", total)
            print("Taxes:", taxes)
            print("Total Due:", total+taxes)
            print()
            print("_________________________________________")


            #customer information print
            print("Customer Info: ")
            print("Customer's Name:", f_name+" "+l_name)
            print("Phone Number: ", phone)
            print("Email: ", email)
            print("Credit Card: ",cc)
            print("Expiration Date:", exp_date)
            print()
            print("Thank you for buying with the AI bot!")

        else:
            #if customer declines 
            print("Sorry our prices weren't good enough for you :(")
            print("Thanks for trying me out, ", f_name, " ", l_name, ".", " ", "Goodbye!")   
    else:
        print("You are being transferred to an agent. Sorry to see you go", f_name ," " ,l_name, "!", "Thanks for giving me a chance :)")
        print()

    print()
    cont=input("Would you like to continue? (y/n)")
# Out:
# Welcome to the AI Bot!
# Sound great  . Thank you for using me
# __________________________________
# Before we get started, I would need some information from you. Please be kind to me, as I am only a program and I am no human.
# You are being transferred to an agent. Sorry to see you go     ! Thanks for giving me a chance :)
